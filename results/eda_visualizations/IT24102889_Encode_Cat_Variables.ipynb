# %%
# --- Setup & Load ---
import numpy as np, pandas as pd
from pathlib import Path

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", rc={"figure.figsize": (8, 4)})

# sklearn (for encoding)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer  # safe guard for categoricals

# ===== paths (portable) =====
ROOT = Path.cwd()
if (ROOT / "notebooks").exists() and not (ROOT / "results").exists():
    ROOT = ROOT.parent

DATA_PATH   = Path(r"C:\Users\Abdur Rahman\AIML_PROJECT\data\after_missing.csv")
VIZ_DIR     = Path(r"C:\Users\Abdur Rahman\AIML_PROJECT\eda_visualizations")
OUT_DIR     = Path(r"C:\Users\Abdur Rahman\AIML_PROJECT\outputs")

VIZ_DIR.mkdir(parents=True, exist_ok=True)
OUT_DIR.mkdir(parents=True, exist_ok=True)

print("Figures →", VIZ_DIR.resolve())
print("Outputs →", OUT_DIR.resolve())
print("CSV exists?", DATA_PATH.exists())

# Load
df = pd.read_csv(DATA_PATH)
display(df.head(3))
print(df.shape)
df.info()
# Out:
# Figures → C:\Users\Abdur Rahman\AIML_PROJECT\eda_visualizations
# Outputs → C:\Users\Abdur Rahman\AIML_PROJECT\outputs
# CSV exists? True
#       FL_DATE OP_UNIQUE_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  DEP_TIME  \
# 0  2019-01-01                9E               3280    GNV  ATL     601.0
# 1  2019-01-01                9E               3281    MSP  CVG    1359.0
# 2  2019-01-01                9E               3282    DTW  CVG    1215.0
#
#    DEP_DELAY  TAXI_OUT  WHEELS_OFF  WHEELS_ON  TAXI_IN  ARR_TIME  ARR_DELAY  \
# 0        1.0      22.0       623.0      714.0      8.0     722.0       -1.0
# 1       -5.0      15.0      1414.0     1629.0      4.0    1633.0      -36.0
# 2       -5.0      18.0      1233.0     1323.0      6.0    1329.0      -16.0
#
#    AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0      51.0     300.0            0.0            0.0        0.0
# 1      75.0     596.0            0.0            0.0        0.0
# ...
